# %%
import pandas as pd

# %%
df1=pd.read_csv('changeover_cost.csv')
df2=pd.read_csv('changeover_days.csv')
df3=pd.read_csv('delivery_cost.csv')
df4=pd.read_csv('demand_price.csv')
df5=pd.read_csv('fixed_cost.csv')
df6=pd.read_csv('forecast_ideal.csv')
df7=pd.read_csv('ideal_manufacture_sequence.csv')
df8=pd.read_csv('ideal_shipping_region.csv')
df9=pd.read_csv('production_capacity.csv')
df10=pd.read_csv('production_cost.csv')

# %%
df1
# Out:
#   Plant  Line      Cost
# 0     A     1  33536.00
# 1     A     2  15947.00
# 2     B     1  13333.00
# 3     B     2  13333.00
# 4     B     3  13333.00
# 5     C     1  54353.39

# %%
df2
# Out:
#      From   To  Days
# 0      P1   P1     0
# 1      P2   P1     1
# 2      P3   P1     1
# 3      P4   P1     1
# 4      P5   P1     1
# 5      P6   P1     1
# 6      P7   P1     1
# 7      P8   P1     1
# 8      P9   P1     1
# 9     P10   P1     1
# 10    P11   P1     1
# 11    P12   P1     1
# 12    P13   P1     2
# 13    P14   P1     2
# 14    P15   P1     2
# 15    P16   P1     2
# 16    P17   P1     2
# 17    P18   P1     2
# 18    P19   P1     2
# 19    P20   P1     2
# 20    P21   P1     2
# 21    P22   P1     2
# 22    P23   P1     2
# 23    P24   P1     2
# 24    P25   P1     2
# 25    P26   P1     2
# 26    P27   P1     2
# 27    P28   P1     2
# 28    P29   P1     2
# 29    P30   P1     2
# ...   ...  ...   ...
# 6531  P52  P81    10
# 6532  P53  P81    10
# 6533  P54  P81    10
# 6534  P55  P81     2
# 6535  P56  P81     2
# 6536  P57  P81     2
# 6537  P58  P81     2
# 6538  P59  P81     2
# 6539  P60  P81     2
# 6540  P61  P81     2
# 6541  P62  P81     2
# ...

# %%
df3
# Out:
#    Plant Region  Delivery_cost
# 0      A     R1      85.541475
# 1      A     R2     223.934332
# 2      A     R3      34.648618
# 3      A     R4      32.059332
# 4      A     R5     121.255760
# 5      A     R6      34.648618
# 6      A     R7     139.112903
# 7      A     R8     114.112903
# 8      A     R9     130.184332
# 9      A    R10     112.327189
# 10     A    R11     148.041475
# 11     A    R12      34.648618
# 12     A    R13      34.648618
# 13     A    R14     121.255760
# 14     A    R15      31.970046
# 15     A    R16     165.898618
# 16     A    R17      81.077189
# 17     A    R18     107.862903
# 18     B     R1      63.000000
# 19     B     R2     287.000000
# 20     B     R3      90.000000
# 21     B     R4      41.000000
# 22     B     R5     144.000000
# 23     B     R6      59.000000
# 24     B     R7     153.000000
# 25     B     R8     242.000000
# 26     B     R9     130.000000
# 27     B    R10     113.000000
# 28     B    R11     233.000000
# ...

# %%
df4
# Out:
#      Product_ID Region  Demand_price
# 0            P1     R1      0.000000
# 1            P2     R1      0.000000
# 2            P3     R1      0.000000
# 3            P4     R1      0.000000
# 4            P5     R1      0.000000
# 5            P6     R1      0.000000
# 6            P7     R1      0.000000
# 7            P8     R1      0.000000
# 8            P9     R1      0.000000
# 9           P10     R1      0.000000
# 10          P11     R1      0.000000
# 11          P12     R1      0.000000
# 12          P13     R1      0.000000
# 13          P14     R1      0.000000
# 14          P15     R1      0.000000
# 15          P16     R1      0.000000
# 16          P17     R1      0.000000
# 17          P18     R1      0.000000
# 18          P19     R1      0.000000
# 19          P20     R1      0.000000
# 20          P21     R1      0.000000
# 21          P22     R1      0.000000
# 22          P23     R1      0.000000
# 23          P24     R1      0.000000
# ...

# %%
df5
# Out:
#   Plant  Line      Cost
# 0     A     1  33536.00
# 1     A     2  15947.00
# 2     B     1  13333.00
# 3     B     2  13333.00
# 4     B     3  13333.00
# 5     C     1  54353.39

# %%
df6
# Out:
#      Product_ID Region  Month  Demand
# 0            P1     R1     34    0.00
# 1            P1     R1     35    0.00
# 2            P1     R1     36    0.00
# 3            P1    R10     34    0.00
# 4            P1    R10     35    0.00
# 5            P1    R10     36    0.00
# 6            P1    R11     34    0.00
# 7            P1    R11     35    0.00
# 8            P1    R11     36    0.00
# 9            P1    R12     34    0.00
# 10           P1    R12     35    0.00
# 11           P1    R12     36    0.00
# 12           P1    R13     34    0.00
# 13           P1    R13     35    0.00
# 14           P1    R13     36    0.00
# 15           P1    R14     34    0.00
# 16           P1    R14     35    0.00
# 17           P1    R14     36    0.00
# 18           P1    R15     34    0.00
# 19           P1    R15     35    0.00
# 20           P1    R15     36    0.00
# 21           P1    R16     34    0.00
# 22           P1    R16     35    0.00
# 23           P1    R16     36    0.00
# ...

# %%
df7
# Out:
#     Plant  Line  Month  Day Product_ID
# 0       A     1     34    1         P3
# 1       A     1     34    2         P3
# 2       A     1     34    3        NaN
# 3       A     1     34    4         P8
# 4       A     1     34    5        NaN
# 5       A     1     34    6        NaN
# 6       A     1     34    7        P13
# 7       A     1     34    8        P13
# 8       A     1     34    9        P13
# 9       A     1     34   10        P13
# 10      A     1     34   11        NaN
# 11      A     1     34   12        NaN
# 12      A     1     34   13        NaN
# 13      A     1     34   14        NaN
# 14      A     1     34   15        NaN
# 15      A     1     34   16        NaN
# 16      A     1     34   17        NaN
# 17      A     1     34   18        NaN
# 18      A     1     34   19        NaN
# 19      A     1     34   20        NaN
# 20      A     1     34   21        P57
# 21      A     1     34   22        P57
# 22      A     1     34   23        P57
# ...

# %%
df8
# Out:
#       Plant Region Product_ID  Month  Shipping_to_region_quantity
# 0         A     R1         P1     34                          0.0
# 1         A     R1         P2     34                          0.0
# 2         A     R1         P3     34                          0.0
# 3         A     R1         P4     34                          0.0
# 4         A     R1         P5     34                          0.0
# 5         A     R1         P6     34                          0.0
# 6         A     R1         P7     34                          0.0
# 7         A     R1         P8     34                          0.0
# 8         A     R1         P9     34                          0.0
# 9         A     R1        P10     34                          0.0
# 10        A     R1        P11     34                          0.0
# 11        A     R1        P12     34                          0.0
# 12        A     R1        P13     34                          0.0
# ...

# %%
df9
# Out:
#     Plant  Line Product  Capacity
# 0       A     1      P1         0
# 1       A     1      P2         0
# 2       A     1      P3       210
# 3       A     1      P4         0
# 4       A     1      P5       210
# 5       A     1      P6         0
# 6       A     1      P7       165
# 7       A     1      P8       195
# 8       A     1      P9       200
# 9       A     1     P10         0
# 10      A     1     P11         0
# 11      A     1     P12         0
# 12      A     1     P13       125
# 13      A     1     P14         0
# 14      A     1     P15         0
# 15      A     1     P16       125
# 16      A     1     P17         0
# 17      A     1     P18         0
# 18      A     1     P19       125
# 19      A     1     P20         0
# 20      A     1     P21         0
# 21      A     1     P22       120
# 22      A     1     P23         0
# 23      A     1     P24         0
# 24      A     1     P25         0
# 25      A     1     P26         0
# ...

# %%
df10
# Out:
#     Product_ID Plant  Production_cost
# 0           P1     A             0.00
# 1           P2     A             0.00
# 2           P3     A           984.44
# 3           P4     A             0.00
# 4           P5     A          1358.41
# 5           P6     A             0.00
# 6           P7     A           980.85
# 7           P8     A           992.19
# 8           P9     A          1009.49
# 9          P10     A             0.00
# 10         P11     A             0.00
# 11         P12     A             0.00
# 12         P13     A          1110.78
# 13         P14     A             0.00
# 14         P15     A             0.00
# 15         P16     A          1702.13
# 16         P17     A             0.00
# 17         P18     A             0.00
# 18         P19     A          1217.41
# 19         P20     A             0.00
# 20         P21     A             0.00
# 21         P22     A          1123.83
# 22         P23     A             0.00
# 23         P24     A             0.00
# ...
